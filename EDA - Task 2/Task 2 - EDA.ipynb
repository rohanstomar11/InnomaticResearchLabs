# %% [markdown]
# # Task 2 - EDA

# %%
#Importing required basic modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

print("Modules Imported Successfully!")
# Out:
# Modules Imported Successfully!

# %%
#Importing libraries as required
from datetime import date

# %%
#Loading the dataset
df = pd.read_excel('aspiring_minds_employability_outcomes_2015.xlsx')

print('Dataset Loaded Successfully')
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# This dataset was released by Aspiring Minds from the Aspiring Mind Employment Outcome(AMEO, 2015).
# The study is primarily limited only to students with engineering disciplines.
# The dataset contains the employment outcomes of engineering graduates as dependent variables (Salary, Job Titles, and Job Locations) along with the standardized scores from three different areas – cognitive skills, technical skills, and personality skills.
# The dataset also contains demographic features.
# The dataset contains around  40 independent variables and 4000 data points.
# The independent variables are both continuous and categorical.
# The dataset contains a unique identifier for each candidate.

# %%
#Checking the shape of data
df.shape
# Out:
# (3998, 39)

# %%
#Checking the name of columns
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity',
#        'Gender', 'DOB', '10percentage', '10board', '12graduation',
#        '12percentage', '12board', 'CollegeID', 'CollegeTier', 'Degree',
#        'Specialization', 'collegeGPA', 'CollegeCityID', 'CollegeCityTier',
#        'CollegeState', 'GraduationYear', 'English', 'Logical', 'Quant',
#        'Domain', 'ComputerProgramming', 'ElectronicsAndSemicon',
#        'ComputerScience', 'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg',
#        'CivilEngg', 'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None) #changing the settings to display all the columns

# %%
df.head() #Checking the first 5 rows of data
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# ...

# %%
df.tail() #Checking the last 5 rows of the data
# Out:
#      Unnamed: 0      ID  Salary        DOJ                  DOL  \
# 3993      train   47916  280000 2011-10-01  2012-10-01 00:00:00
# 3994      train  752781  100000 2013-07-01  2013-07-01 00:00:00
# 3995      train  355888  320000 2013-07-01              present
# 3996      train  947111  200000 2014-07-01  2015-01-01 00:00:00
# 3997      train  324966  400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 3993            software engineer        New Delhi       m 1987-04-15
# 3994             technical writer         Hyderabad      f 1992-08-27
# 3995  associate software engineer         Bangalore      m 1991-07-03
# 3996           software developer  Asifabadbanglore      f 1992-03-20
# 3997      senior systems engineer           Chennai      f 1991-02-26
#
#       10percentage      10board  12graduation  12percentage      12board  \
# 3993         52.09         cbse          2006         55.50         cbse
# ...

# %%
df.info() #Checking the dTypes of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   int64
#  3   DOJ                    3998 non-null   datetime64[ns]
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   datetime64[ns]
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
# ...

# %%
df.describe() #Statistical info about numerical columns
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
#Checking unique values
df.apply(lambda x: len(x.unique()))
# Out:
# Unnamed: 0                  1
# ID                       3998
# Salary                    177
# DOJ                        81
# DOL                        67
# Designation               419
# JobCity                   339
# Gender                      2
# DOB                      1872
# 10percentage              851
# 10board                   275
# 12graduation               16
# 12percentage              801
# 12board                   340
# CollegeID                1350
# CollegeTier                 2
# Degree                      4
# Specialization             46
# collegeGPA               1282
# CollegeCityID            1350
# CollegeCityTier             2
# CollegeState               26
# GraduationYear             11
# English                   111
# Logical                   107
# Quant                     138
# Domain                    243
# ComputerProgramming        79
# ElectronicsAndSemicon      29
# ComputerScience            20
# MechanicalEngg             42
# ...

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ID                       0
# Salary                   0
# DOJ                      0
# DOL                      0
# Designation              0
# JobCity                  0
# Gender                   0
# DOB                      0
# 10percentage             0
# 10board                  0
# 12graduation             0
# 12percentage             0
# 12board                  0
# CollegeID                0
# CollegeTier              0
# Degree                   0
# Specialization           0
# collegeGPA               0
# CollegeCityID            0
# CollegeCityTier          0
# CollegeState             0
# GraduationYear           0
# English                  0
# Logical                  0
# Quant                    0
# Domain                   0
# ComputerProgramming      0
# ElectronicsAndSemicon    0
# ComputerScience          0
# MechanicalEngg           0
# ElectricalEngg           0
# TelecomEngg              0
# CivilEngg                0
# ...

# %%
#Checking duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.head() #Checking the dataset before moving to EDA
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Uni-Variate Analysis

# %% [markdown]
# #### Salary

# %%
sns.histplot(df['Salary'], kde=True) #Histogram of Salary Distribution
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Count'>

# %% [markdown]
# - Histogram seems right skewed due to outlier present in the data.

# %%
sns.boxplot(df['Salary']) #Salary Boxplot to determine the outliers
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
#Treating the outliers using IQR
salary_low = df['Salary'].quantile(0.25)
salary_high  = df['Salary'].quantile(0.75)
salary_iqr = salary_high - salary_low
salary_left = salary_low-1.5*salary_iqr
salary_right = salary_high+1.5*salary_iqr

df = df[(df['Salary'] <= salary_right) & (df['Salary'] > salary_left)]

# %%
sns.boxplot(df['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary'>

# %%
sns.distplot(df['Salary'])
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %% [markdown]
# - With the removal of outliers, the distribution becomes bit uniform.

# %%
#Let's find the mean and median salary
print("Mean Salary:   ", round(np.mean(df['Salary']), 1))
print("Median Salary: ", np.median(df['Salary']))
# Out:
# Mean Salary:    285447.2
# Median Salary:  300000.0

# %% [markdown]
# #### Job City

# %%
#PreProcessing Job City Column
df['JobCity'] = df['JobCity'].str.strip()
df['JobCity'] = df['JobCity'].str.lower()

df.JobCity[df['JobCity'].isin(['a-64,sec-64,noida', 'greater noida', 'nouda'])] = 'noida'
df.JobCity[df['JobCity'].isin(['am', 'ambala city'])] = 'ambala'
df.JobCity[df['JobCity'].isin(['al jubail,saudi arabia', 'ras al khaimah', 'dammam', 'dubai', 'johannesburg', 'kalmar, sweden', 'london'])] = 'outside india'
df.JobCity[df['JobCity'].isin(['asifabadbanglore', 'banagalore', 'banaglore', 'bangalore', 'banglore', 'chennai, bangalore'])] = 'bengaluru'
df.JobCity[df['JobCity'].isin(['baddi hp'])] = 'baddi'
df.JobCity[df['JobCity'].isin(['bhubneshwar'])] = 'bhubneswar'
df.JobCity[df['JobCity'].isin(['chennai & mumbai'])] = 'chennai'
df.JobCity[df['JobCity'].isin(['delhi/ncr', 'ncr', 'new dehli', 'new delhi', 'new delhi - jaisalmer'])] = 'delhi'
df.JobCity[df['JobCity'].isin(['gandhi nagar'])] = 'gandhinagar'
df.JobCity[df['JobCity'].isin(['gaziabad', 'gajiabaad', 'indirapuram, ghaziabad'])] = 'ghaziabad'
df.JobCity[df['JobCity'].isin(['guragaon', 'gurga', 'gurgoan'])] = 'gurgaon'
df.JobCity[df['JobCity'].isin(['hderabad', 'hyderabad(bhadurpally)'])] = 'hyderabad'
df.JobCity[df['JobCity'].isin(['keral'])] = 'kerala'
df.JobCity[df['JobCity'].isin(['kochi/cochin', 'kochi/cochin, chennai and coimbatore'])] = 'kochi'
df.JobCity[df['JobCity'].isin(['kolkata`'])] = 'kolkata'
df.JobCity[df['JobCity'].isin(['kudankulam ,tarapur'])] = 'tarapur'
df.JobCity[df['JobCity'].isin(['latur (maharashtra )'])] = 'latur'
df.JobCity[df['JobCity'].isin(['mettur, tamil nadu'])] = 'mettur'
df.JobCity[df['JobCity'].isin(['muzzafarpur'])] = 'muzaffarpur'
df.JobCity[df['JobCity'].isin(['nasikcity'])] = 'nashik'
df.JobCity[df['JobCity'].isin(['navi mumbai', 'navi mumbai , hyderabad'])] = 'mumbai'
df.JobCity[df['JobCity'].isin(['pondi', 'pondy'])] = 'pondicherry'
df.JobCity[df['JobCity'].isin(['punr'])] = 'pune'
df.JobCity[df['JobCity'].isin(['rayagada, odisha'])] = 'orissa'
df.JobCity[df['JobCity'].isin(['sadulpur,rajgarh,distt-churu,rajasthan'])] = 'rajasthan'
df.JobCity[df['JobCity'].isin(['shahibabad'])] = 'sahibabad'
df.JobCity[df['JobCity'].isin(['sonepat'])] = 'sonipat'
df.JobCity[df['JobCity'].isin(['technopark, trivandrum', 'trivandrum'])] = 'thiruvananthapuram'
df.JobCity[df['JobCity'].isin(['tirupathi'])] = 'tirupati'
df.JobCity[df['JobCity'].isin(['vsakhapttnam'])] = 'visakhapatnam'


df['JobCity'] = df['JobCity'].fillna(np.nan)

# %%
#Plotting the Job City column
plt.figure(figsize=(12,6))
sns.countplot(y=df['JobCity'], data=df, order=df.JobCity.value_counts().iloc[:10].index)
plt.title('No. of Jobs by City')
# Out:
# Text(0.5, 1.0, 'No. of Jobs by City')

# %% [markdown]
# - Most of the jobs seems to be centered in bangalore.
# - Noida and hyderabad was the most sought out city for job after bangalore.

# %% [markdown]
# #### Gender

# %%
#Plotting the countplot of gender feature
sns.countplot(df.Gender)
df['Gender'].value_counts()
# Out:
# m    2951
# f     938
# Name: Gender, dtype: int64

# %% [markdown]
# #### Date of Birth (Age)

# %%
#Converting the DOB column to age column based on today's date
today = pd.Timestamp(date.today())
df['Age'] = ((today-df['DOB']).dt.days//365)

# %%
#Plotting the age column
sns.countplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# - Most of the employees are currently around 29-31 years old.
# - The age group ranges from 24-44.

# %%
#plotting the age of currently employed
sns.countplot(df.Age[df['DOL']=='present'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# - The age group distribution is nearly same as previous one.

# %% [markdown]
# #### 10th Percentage

# %%
#Finding Mean, Max, Minimum of 10th percentage
print("Minimum: {:.2f}%".format(df['10percentage'].min()))
print("Maximum: {:.2f}%".format(df['10percentage'].max()))
print("Mean % : {:.2f}".format(df['10percentage'].mean()))
# Out:
# Minimum: 43.00%
# Maximum: 97.12%
# Mean % : 77.86

# %%
#Plotting the 10th percentage
sns.histplot(df['10percentage'], kde=True)
# Out:
# <AxesSubplot:xlabel='10percentage', ylabel='Count'>

# %% [markdown]
# - Most of the employees scored between 70% - 90% in their 10th.

# %% [markdown]
# #### 12 Graduation

# %%
#Plotting the 12th Graduation year
plt.figure(figsize=(12,6))
sns.histplot(df['12graduation'], binwidth=1.0, kde=True)
# Out:
# <AxesSubplot:xlabel='12graduation', ylabel='Count'>

# %% [markdown]
# - Most of the employees cleared their 12th between 2008-2010.

# %% [markdown]
# #### 12 Percentage

# %%
#Find Minimum, Maximum and Mean of 12th percentage
print("Minimum: {:.2f}%".format(df['12percentage'].min()))
print("Maximum: {:.2f}%".format(df['12percentage'].max()))
print("Mean % : {:.2f}".format(df['12percentage'].mean()))
# Out:
# Minimum: 40.00%
# Maximum: 98.70%
# Mean % : 74.42

# %%
#Plotting the 12th percentage column
sns.histplot(df['12percentage'], kde=True)
# Out:
# <AxesSubplot:xlabel='12percentage', ylabel='Count'>

# %% [markdown]
# - Most of the employees scored between 60% - 80% in their 12th.

# %% [markdown]
# #### College Tier

# %%
#total value count of each college tier
pd.DataFrame(df['CollegeTier'].value_counts())
# Out:
#    CollegeTier
# 2         3626
# 1          263

# %%
#Countplot for college tier feature
sns.countplot(df['CollegeTier'])
# Out:
# <AxesSubplot:xlabel='CollegeTier', ylabel='count'>

# %% [markdown]
# - Most of the college were 2nd Tier.

# %% [markdown]
# #### Degree

# %%
#Plotting Degree column
sns.countplot(df.Degree)
# Out:
# <AxesSubplot:xlabel='Degree', ylabel='count'>

# %% [markdown]
# - Most of the employee did graduation in B.Tech or B.E..

# %% [markdown]
# #### Specialization

# %%
#Changing some specialization fields
df.Specialization[df['Specialization'].isin(['computer application', 'computer engineering', 'computer networking', 'computer science', 'computer science & engineering', 'computer science and technology'])] = 'computer'
df.Specialization[df['Specialization'].isin(['information science', 'information science engineering'])] = 'information technology'

# %%
#Plotting the Specialization column
plt.figure(figsize=(12,6))
sns.countplot(y=df['Specialization'], data=df, order=df.Specialization.value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Specialization'>

# %% [markdown]
# - Most of the employees scpecialized in computer science or computer science engineering.
# - Followed by ECE and IT.

# %% [markdown]
# #### College GPA

# %%
#Plotting college GPA column
sns.histplot(df['collegeGPA'], kde=True)
# Out:
# <AxesSubplot:xlabel='collegeGPA', ylabel='Count'>

# %% [markdown]
# - It seems most of the collegeGPA is out of 100, but few entries might have mistakenly gaev it out of 10.

# %%
#Changing the GPA(out of 10) to GPA(out of 100)
df.collegeGPA[df['collegeGPA'] < 10] = df.collegeGPA[df['collegeGPA'] < 10].apply(lambda x: x*10)

# %%
#College GPA column after outlier treatment
sns.histplot(df['collegeGPA'], kde=True)
# Out:
# <AxesSubplot:xlabel='collegeGPA', ylabel='Count'>

# %% [markdown]
# - Now, the distribution seems uniform.

# %% [markdown]
# #### College State

# %%
#Plotting the College State column
plt.figure(figsize=(12,6))
sns.countplot(y=df['CollegeState'], data=df, order=df.CollegeState.value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='CollegeState'>

# %% [markdown]
# - Most of the employees were from UP.
# - Followed by karnataka and Tamil Nadu, which had nearly same count.

# %% [markdown]
# #### Graduation Year

# %%
#Changing the values which had graduation year as 0 to 2014
df.GraduationYear[df.GraduationYear == 0] = 2014

# %%
#Plotting Graduation Year
sns.countplot(df.GraduationYear)
# Out:
# <AxesSubplot:xlabel='GraduationYear', ylabel='count'>

# %% [markdown]
# #### Score in English

# %%
#Finding Minimum, Maximum, and Mean for score in English.
print("Minimum: ", df['English'].min())
print("Maximum: ", df['English'].max())
print("Mean   :  {:.2f}".format(df['English'].mean()))
# Out:
# Minimum:  180
# Maximum:  875
# Mean   :  500.61

# %%
#Plotting English feature
sns.histplot(df.English, kde=True)
# Out:
# <AxesSubplot:xlabel='English', ylabel='Count'>

# %% [markdown]
# #### Logical

# %%
#Finding Minimum, Maximum, and Mean for score in Logical.
print("Minimum: ", df['Logical'].min())
print("Maximum: ", df['Logical'].max())
print("Mean   :  {:.2f}".format(df['Logical'].mean()))
# Out:
# Minimum:  195
# Maximum:  795
# Mean   :  500.78

# %%
#Plotting the logical feature
sns.histplot(df.Logical, kde=True)
# Out:
# <AxesSubplot:xlabel='Logical', ylabel='Count'>

# %% [markdown]
# ### Bi-Variate Analysis

# %%
#Ratio difference between Gender
num_males = df['Gender'].where(df['Gender'] == 'm').count()
num_females = df['Gender'].where(df['Gender'] == 'f').count()
print('Number of male candidates : {}'.format(num_males))
print('Number of female candidates : {}'.format(num_females))
print('Male to Female ratio: {:.2f}'.format(num_males/num_females))
# Out:
# Number of male candidates : 2951
# Number of female candidates : 938
# Male to Female ratio: 3.15

# %%
#Boxplot of Salary by gender
sns.boxplot(x='Salary', y = 'Gender', data=df)
plt.suptitle('Salary levels by gender')
# Out:
# Text(0.5, 0.98, 'Salary levels by gender')

# %% [markdown]
# - Salaray ranges a lot more in female than male.

# %%
#Regplot between Logial and Salary
sns.regplot(x='Logical', y='Salary', data=df)
# Out:
# <AxesSubplot:xlabel='Logical', ylabel='Salary'>

# %% [markdown]
# - There is a slightly postive correlation between Logical Score and Salary.

# %%
#Average Score feature using logical, Quant and English Score.
df['AverageScore']=(df['Logical']+df['Quant']+df['English'])/3

# %%
#Plotting Average Score and Salary
sns.regplot(x='AverageScore', y='Salary', data=df)
# Out:
# <AxesSubplot:xlabel='AverageScore', ylabel='Salary'>

# %% [markdown]
# - There is a positive correlation between AverageScore and Salary.

# %%
#Plotting the heatmap for corelation matrix
plt.figure(figsize= (7,7), dpi=100)
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#Regplot between Salary and Computer Programming Skills
sns.regplot(x='ComputerProgramming', y='Salary', data=df)
# Out:
# <AxesSubplot:xlabel='ComputerProgramming', ylabel='Salary'>

# %% [markdown]
# - Slightly positive correlation between the features.

# %%
#Plotting the pairplot between different hand picked features
df_1 = df[['10percentage', '12percentage', 'collegeGPA', 'English', 'Logical', 'Quant', 'Gender', 'Salary']]
sns.pairplot(df_1, hue='Gender')

# %% [markdown]
# - Pairplots between different features.

# %% [markdown]
# ## Research Question

# %% [markdown]
# **Times of india dated Jan 18, 2019 states that "After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, software Engineer, Hardware engineer and Associate Engineer you can earn upto 2.5 - 3 Lakhs as a fresher graduate." Test this claim with the given data.**

# %%
#Creating new df on the basis of condition stated in research question
df_be = df[df['Degree']=='B.Tech/B.E.']
df_be_comp = df_be[df_be['Specialization']=='computer']

# %%
#Creatinf new df on basis of designation
designation = df_be_comp[(df_be_comp['Designation']=='programmer analyst') | (df_be_comp['Designation']=='software engineer') | (df_be_comp['Designation']=='software engineere') | (df_be_comp['Designation']=='associate software engineer')]
salary = designation[['Salary']]

# %%
#Average Salary by 2 different methods
print("Average Salary(by Median):",salary.median()[0])
print("Average Salary(by Mean):  ",round(salary.mean()[0],1))
# Out:
# Average Salary(by Median): 330000.0
# Average Salary(by Mean):   333778.1

# %% [markdown]
# We accept the given claim that - **"After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, software Engineer, Hardware engineer and Associate Engineer you can earn upto 2.5 - 3 Lakhs as a fresher graduate."**

# %% [markdown]
# - **Is there a relationship between gender and specialisation? (i.e. Does the preference of Specialisation depend on the Gender?)**

# %%
#Plotting the category column
plt.figure(figsize=(12,6))
sns.countplot(y=df['Specialization'], data=df, hue=df['Gender'], order=df.Specialization.value_counts().iloc[:10].index)
plt.title('No. of Projects by Category')
# Out:
# Text(0.5, 1.0, 'No. of Projects by Category')

# %% [markdown]
# - Yes, the preference of specialization depends on gender.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We present in this work details of Aspiring Minds’ Employability Outcomes 2015 (AMEO 2015), the first dataset to provide engineers’ employment outcomes (salaries, job titles, and job locations) together with standardized assessment scores in three fundamental areas - cognitive skills, technical skills, and personality. The dataset also contains anonymized biodata, making it a rich source for a comprehensive study of the entry-level labor markets. We see it being used in analyses that can inform policies on personnel selection and higher education. It can also be used to model a variety of data-driven systems which can efficiently match job seekers and job providers. Systems like these include accurate salary predictors, automated job counselors, and visualizations on how skills are distributed across geographies. We look forward to this dataset being utilized in the design of a truly merit-driven labor market.
